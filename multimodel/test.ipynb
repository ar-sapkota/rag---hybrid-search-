# %% [markdown]
# ## Agenda
# * Document Structure
# * Complex RAG Pipeline
#   * Data ingestion pipeline
#   * data retrieval pipeline
#
# * How it works ?
#   * data ingestion
#   * chunking
#   * embedding
#   * store in vector db
#   * similarity search

# %% [markdown]
# ## Data ingestion
# ### Document datastructure

# %% [markdown]
# # Steps
# ## Data Ingestion
# * Import langchain
# * Sample Langchain Document
# * create sample text file
# * Load text using TextLoader
#     * text loader give data in document structure with metadata
# * Directory loader
#     * get all documents inside directory.
# * PypdfLoader, PyMuPDF
#     * load and give pdf in document format.

# %% [markdown]
# ## RAG Pipelines- Data Ingestion to Vector DB Pipeline
# * import
# * Read all the pdf inside the directory
#     * find all pdf file
#     * add source info to metadata
#     * process all pdf in directory

# %% [markdown]
# ### Chunking
# * Text splitting get into chunks
#     * function splits_documents
#     * use recursive character text splitter
#     * chunksize and chunkoverlap is passed as parameters
#     * separators are used
#     * show example of documents and return split_docs

# %% [markdown]
# ### Embedding and vectorStoreDB
# * sentence-transformers -> library for embedding
# * faiss-cpu, chromadb -> vector db
# *
